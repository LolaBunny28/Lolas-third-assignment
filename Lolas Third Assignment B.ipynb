# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import datetime

# %%
CarsPrice = pd.read_csv('Automobile Price Data.csv')
CarsPrice.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
CarsPrice.shape
# Out:
# (205, 26)

# %%
Replace the '?' value with NaN values

# %%
CarsPrice = CarsPrice.replace('?', np.nan)
CarsPrice.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
CarsPrice = CarsPrice.dropna()

# %%
CarsPrice.head(5)
# Out:
#     symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 3           2               164  audi       gas        std         four
# 4           2               164  audi       gas        std         four
# 6           1               158  audi       gas        std         four
# 8           1               158  audi       gas      turbo         four
# 10          2               192   bmw       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3       sedan          fwd           front        99.8  ...          109
# 4       sedan          4wd           front        99.4  ...          136
# 6       sedan          fwd           front       105.8  ...          136
# 8       sedan          fwd           front       105.8  ...          131
# 10      sedan          rwd           front       101.2  ...          108
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
CarsPrice.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
CarsPrice.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
CarsPrice1 = CarsPrice[CarsPrice['normalized-losses']!='?']
normalised_mean = CarsPrice['normalized-losses'].astype(int).mean()
CarsPrice['normalized-losses'] = CarsPrice['normalized-losses'].replace('?',normalised_mean).astype(int)

# %%
CarsPrice1 = CarsPrice[CarsPrice['price']!='?']
normalised_mean = CarsPrice1['price'].astype(int).mean()
CarsPrice['price'] = CarsPrice['price'].replace('?',normalised_mean).astype(int)

# %%
CarsPrice1 = CarsPrice[CarsPrice['peak-rpm']!='?']
normalised_mean = CarsPrice1['peak-rpm'].astype(int).mean()
CarsPrice['peak-rpm'] = CarsPrice['peak-rpm'].replace('?',normalised_mean).astype(int)

# %%
CarsPrice1 = CarsPrice[CarsPrice['horsepower']!='?']
normalised_mean = CarsPrice1['horsepower'].astype(int).mean()
CarsPrice['horsepower'] = CarsPrice['horsepower'].replace('?',normalised_mean).astype(int)

# %%
CarsPrice1 = CarsPrice[CarsPrice['bore']!='?']
normalised_mean = CarsPrice1['bore'].astype(float).mean()
CarsPrice['bore'] = CarsPrice['bore'].replace('?',normalised_mean).astype(float)

# %%
CarsPrice1 = CarsPrice[CarsPrice['stroke']!='?']
normalised_mean = CarsPrice1['stroke'].astype(float).mean()
CarsPrice['stroke'] = CarsPrice['stroke'].replace('?',normalised_mean).astype(float)

# %%
CarsPrice['num-of-doors'] = CarsPrice['num-of-doors'].replace('?','four')
CarsPrice.head()
# Out:
#     symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 3           2                164  audi       gas        std         four
# 4           2                164  audi       gas        std         four
# 6           1                158  audi       gas        std         four
# 8           1                158  audi       gas      turbo         four
# 10          2                192   bmw       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3       sedan          fwd           front        99.8  ...          109
# 4       sedan          4wd           front        99.4  ...          136
# 6       sedan          fwd           front       105.8  ...          136
# 8       sedan          fwd           front       105.8  ...          131
# 10      sedan          rwd           front       101.2  ...          108
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
CarsPrice.drop(['bore', 'stroke', 'compression-ratio'], inplace=True, axis=1)
CarsPrice.head()
# Out:
#     symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 3           2                164  audi       gas        std         four
# 4           2                164  audi       gas        std         four
# 6           1                158  audi       gas        std         four
# 8           1                158  audi       gas      turbo         four
# 10          2                192   bmw       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  curb-weight  \
# 3       sedan          fwd           front        99.8  ...         2337
# 4       sedan          4wd           front        99.4  ...         2824
# 6       sedan          fwd           front       105.8  ...         2844
# 8       sedan          fwd           front       105.8  ...         3086
# 10      sedan          rwd           front       101.2  ...         2395
#
#     engine-type  num-of-cylinders  engine-size fuel-system horsepower  \
# ...

# %%
CarsPrice.drop(['make', 'aspiration', 'drive-wheels', 'body-style'], inplace=True, axis=1)
CarsPrice.head()
# Out:
#     symboling  normalized-losses fuel-type num-of-doors engine-location  \
# 3           2                164       gas         four           front
# 4           2                164       gas         four           front
# 6           1                158       gas         four           front
# 8           1                158       gas         four           front
# 10          2                192       gas          two           front
#
#     wheel-base  length  width  height  curb-weight engine-type  \
# 3         99.8   176.6   66.2    54.3         2337         ohc
# 4         99.4   176.6   66.4    54.3         2824         ohc
# 6        105.8   192.7   71.4    55.7         2844         ohc
# 8        105.8   192.7   71.4    55.9         3086         ohc
# 10       101.2   176.8   64.8    54.3         2395         ohc
#
#    num-of-cylinders  engine-size fuel-system  horsepower  peak-rpm  city-mpg  \
# ...

# %%
CarsPrice.drop(['symboling', 'fuel-type', 'fuel-system'], inplace=True, axis=1)
CarsPrice.head()
# Out:
#     normalized-losses num-of-doors engine-location  wheel-base  length  width  \
# 3                 164         four           front        99.8   176.6   66.2
# 4                 164         four           front        99.4   176.6   66.4
# 6                 158         four           front       105.8   192.7   71.4
# 8                 158         four           front       105.8   192.7   71.4
# 10                192          two           front       101.2   176.8   64.8
#
#     height  curb-weight engine-type num-of-cylinders  engine-size  horsepower  \
# 3     54.3         2337         ohc             four          109         102
# 4     54.3         2824         ohc             five          136         115
# 6     55.7         2844         ohc             five          136         110
# 8     55.9         3086         ohc             five          131         140
# 10    54.3         2395         ohc             four          108         101
#
# ...

# %%
CarsPrice.describe()
# Out:
#        normalized-losses  wheel-base      length       width      height  \
# count         159.000000  159.000000  159.000000  159.000000  159.000000
# mean          121.132075   98.264151  172.413836   65.607547   53.899371
# std            35.651285    5.167416   11.523177    1.947883    2.268761
# min            65.000000   86.600000  141.100000   60.300000   49.400000
# 25%            94.000000   94.500000  165.650000   64.000000   52.250000
# 50%           113.000000   96.900000  172.400000   65.400000   54.100000
# 75%           148.000000  100.800000  177.800000   66.500000   55.500000
# max           256.000000  115.600000  202.600000   71.700000   59.800000
#
#        curb-weight  engine-size  horsepower     peak-rpm    city-mpg  \
# count   159.000000   159.000000  159.000000   159.000000  159.000000
# mean   2461.138365   119.226415   95.836478  5113.836478   26.522013
# std     481.941321    30.460791   30.718583   465.754864    6.097142
# ...

# %%
CarsPrice.to_csv('CarsPriceCleaned.csv', index=False)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 8))
plt.bar(CarsPrice['engine-size'], CarsPrice['price'])
plt.xlabel('engine-size')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(CarsPrice['curb-weight'], CarsPrice['price'], color='g')
plt.xlabel('curb-weight')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(CarsPrice['peak-rpm'], CarsPrice['price'], color='r')
plt.xlabel('peak-rpm')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.figure(figsize=(8, 8))
plt.scatter(CarsPrice['horsepower'], CarsPrice['price'], color='r')
plt.xlabel('horsepower')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
CarsPrice[['engine-size','peak-rpm','curb-weight','horsepower','price']].hist(figsize=(10,8),bins=6,color='Y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # END OF B
